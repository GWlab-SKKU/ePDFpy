# %%
import mrcfile
import file
from pathlib import Path
import glob
import numpy as np
import image_process
import matplotlib.pyplot as plt
import cv2
from datacube import DataCube
import plotly.offline as pyo
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import numpy as np

# %%
mrc_search_path = '/mnt/experiment/TEM diffraction/'
mrc_file_paths = [str(i) for i in Path(mrc_search_path).rglob("*.mrc")]

# %%
dc = DataCube(mrc_file_paths[0])

# %%
dc.ready()

# %%
plt.imshow(dc.img)

# %%
from rdfpy import rdf

# %%
g_r, radii = rdf(dc.img, dr=0.05)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-10-73528affc6bb> in <module>
# ----> 1 g_r, radii = rdf(dc.img, dr=0.05)
#
# ~/anaconda3/envs/cv/lib/python3.7/site-packages/rdfpy/rdfpy.py in rdf(particles, dr, rho, rcutoff, eps, parallel, progress)
#      79     # assert particle coords are 2 or 3 dimensional
#      80     assert particles.shape[-1] in [2, 3], 'RDF can only be computed in 2 or 3 \
# ---> 81                                            dimensions.'
#      82
#      83     start = time.time()
#
# AssertionError: RDF can only be computed in 2 or 3                                            dimensions.

# %%
dc.img.shape[-1]
# Out:
# 2048

# %%
from pymatgen.core import structure
structure = Structure('/home/pilsung/Downloads/Ti_mp-46_computed.cif')
pymatgen.structure.make_supercell(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-7bb878dcc2f0> in <module>
#       1 from pymatgen.core import structure
# ----> 2 structure = Structure('/home/pilsung/Downloads/Ti_mp-46_computed.cif')
#       3 pymatgen.structure.make_supercell(10)
#
# TypeError: __init__() missing 2 required positional arguments: 'species' and 'coords'
