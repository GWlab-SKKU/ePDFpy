# %%
# https://learnopencv.com/getting-started-opencv-cuda-module/
import cv2

# %%
img = cv2.imread("3d.png", cv2.IMREAD_GRAYSCALE)
src = cv2.cuda_GpuMat()
src.upload(img)

# %%
clahe = cv2.cuda.createCLAHE(clipLimit=5.0, tileGridSize=(8, 8))

# %%
dst = clahe.apply(src, cv2.cuda_Stream.Null())

# %%
result = dst.download()
cv2.imshow("result", result)
cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-12-999487cc5501> in <module>
#       1 result = dst.download()
# ----> 2 cv2.imshow("result", result)
#       3 cv2.waitKey(0)
#
# error: OpenCV(4.5.1) /home/pilsung/opencv/opencv-4.5.1/modules/highgui/src/window_gtk.cpp:624: error: (-2:Unspecified error) Can't initialize GTK backend in function 'cvInitSystem'

# %%
import matplotlib.pyplot as plt
plt.imshow(result)
