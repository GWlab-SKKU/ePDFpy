# %%
import util
import matplotlib.pyplot as plt
import matplotlib
from datacube import DataCube
import rdf_calculator
from scipy.ndimage.filters import gaussian_filter1d
from scipy.signal import find_peaks
import numpy as np
import file

# %%
matplotlib.rcParams['figure.figsize'] = [10,10]
# %matplotliblib qt
# Out:
# UsageError: Line magic function `%matplotliblib` not found.

# %%
def find_first_peak(azavg, derivative=0):
    # flattening
    first_peak_idx = 1
    for i in range(len(azavg)):
        if azavg[i] != 0:
            first_peak_idx = i
            break
    min_limit = first_peak_idx+int(len(azavg)/100)
    gaussian_sigma = 10
    range_slice = slice(first_peak_idx, first_peak_idx + int(len(azavg) * 0.3))
    filtered_part = gaussian_filter1d(azavg[first_peak_idx:first_peak_idx + int(len(azavg) * 0.3)], sigma=gaussian_sigma)
    azavg2 = azavg.copy()
    azavg2[range_slice] = filtered_part
    
    # first order
    x = azavg2[0:int(len(azavg) * 0.3)]
    low_peaks, _ = find_peaks(-x, distance=20)

    if len(low_peaks) > 0 and (derivative is not 2):
        plt.plot(azavg2[:300], label="smoothed") # plot smooth graph
        plt.legend()
        return low_peaks[0]
    if derivative == 1:
        return None

    # second order
    else:
        x = np.gradient(azavg2, 0.1)
        # peaks, _ = find_peaks(x, distance=20)
        low_peaks, _ = find_peaks(-x, distance=20)

        # peaks = peaks[azavg2[peaks] != 0]
        low_peaks = low_peaks[azavg2[low_peaks] != 0]

        
        for lp in low_peaks:
            if lp>min_limit:
                plt.plot(azavg2[:300], label="smoothed") # plot smooth graph
                plt.legend()
                return lp
        return None

# %%
dcs = [DataCube(fp) for fp in file.get_file_list_from_path("/mnt/experiment/TEM diffraction/210311",".mrc")]
indices = range(len(dcs))
for idx in indices:
    print(dcs[idx].file_path[32:])
    print("index_num =",idx)
    util.load_previous_tiff(dcs[idx])
    util.load_previous_dc_azavg(dcs[idx])
#     plt.imshow(dcs[idx].display_img)
#     plt.show()
    
    plt.plot(dcs[idx].azavg[0:300], label="original")
    plt.legend()
    
    first_derv_peak = find_first_peak(dcs[idx].azavg,1)
    second_derv_peak = find_first_peak(dcs[idx].azavg,2)
    if first_derv_peak is not None:
        plt.scatter(first_derv_peak,dcs[idx].azavg[first_derv_peak],color='r')
    if second_derv_peak is not None:
        plt.scatter(second_derv_peak,dcs[idx].azavg[second_derv_peak],color='b')
    plt.show()
# Out:
# 210311/sample46_TiGe27_bot_AD/Camera 230 mm Ceta 20210311 1545_50s_20f_area09.mrc
# index_num = 0
# 210311/sample46_TiGe27_bot_AD/Camera 230 mm Ceta 20210311 1541_50s_20f_area08_afterMoving2.mrc
# index_num = 1
# 210311/sample46_TiGe27_bot_AD/Camera 230 mm Ceta 20210311 1428_80s_20f_area03.mrc
# index_num = 2
# 210311/sample46_TiGe27_bot_AD/Camera 230 mm Ceta 20210311 1519_50s_20f_area05.mrc
# index_num = 3
# 210311/sample46_TiGe27_bot_AD/Camera 230 mm Ceta 20210311 1425_70s_20f_area03.mrc
# index_num = 4
# 210311/sample46_TiGe27_bot_AD/Camera 230 mm Ceta 20210311 1413_50s_20f_area02_image.mrc
# index_num = 5
# 210311/sample46_TiGe27_bot_AD/Camera 230 mm Ceta 20210311 1407_40s_20f_area01.mrc
# index_num = 6
# 210311/sample46_TiGe27_bot_AD/Camera 230 mm Ceta 20210311 1405_2s_1f_reduceNoise.mrc
# index_num = 7
# 210311/sample46_TiGe27_bot_AD/Camera 230 mm Ceta 20210311 1405_2s_1f_area01.mrc
# index_num = 8
# 210311/sample46_TiGe27_bot_AD/Camera 230 mm Ceta 20210311 1418_50s_20f_area03.mrc
# index_num = 9
# 210311/sample46_TiGe27_bot_AD/Camera 230 mm Ceta 20210311 1532_50s_20f_area08.mrc
# index_num = 10
# 210311/sample46_TiGe27_bot_AD/Camera 230 mm Ceta 20210311 1528_50s_20f_area07.mrc
# index_num = 11
# 210311/sample46_TiGe27_bot_AD/Camera 230 mm Ceta 20210311 1413_50s_20f_area02.mrc
# index_num = 12
# 210311/sample46_TiGe27_bot_AD/Camera 230 mm Ceta 20210311 1525_50s_20f_area06.mrc
# index_num = 13
# 210311/sample46_TiGe27_bot_AD/Camera 230 mm Ceta 20210311 1418_50s_20f_area03_image.mrc
# index_num = 14
# 210311/sample46_TiGe27_bot_AD/Camera 230 mm Ceta 20210311 1422_60s_20f_area03.mrc
# index_num = 15
# 210311/sample46_TiGe27_bot_AD/Camera 230 mm Ceta 20210311 1537_50s_20f_area08_afterMoving.mrc
# index_num = 16
# 210311/sample46_TiGe27_bot_AD/Camera 230 mm Ceta 20210311 1516_50s_20f_area04.mrc
# index_num = 17
# 210311/sample47_TiGe44_bot_AD/Camera 230 mm Ceta 20210311 1507_50s_20f_area06.mrc
# index_num = 18
# 210311/sample47_TiGe44_bot_AD/Camera 230 mm Ceta 20210311 1443_30s_20f_area01.mrc
# index_num = 19
# 210311/sample47_TiGe44_bot_AD/Camera 230 mm Ceta 20210311 1441_40s_20f_area01.mrc
# index_num = 20
# 210311/sample47_TiGe44_bot_AD/Camera 230 mm Ceta 20210311 1457_50s_20f_area04.mrc
# index_num = 21
# 210311/sample47_TiGe44_bot_AD/Camera 44000 x Ceta 20210311 1435_image.mrc
# index_num = 22
# 210311/sample47_TiGe44_bot_AD/Camera 230 mm Ceta 20210311 1436_50s_20f_area01.mrc
# index_num = 23
# 210311/sample47_TiGe44_bot_AD/Camera 230 mm Ceta 20210311 1453_40s_20f_area03.mrc
# index_num = 24
# 210311/sample47_TiGe44_bot_AD/Camera 230 mm Ceta 20210311 1503_50s_20f_area05.mrc
# index_num = 25
# 210311/sample47_TiGe44_bot_AD/Camera 230 mm Ceta 20210311 1448_40s_20f_area02.mrc
# index_num = 26
# 210311/sample47_TiGe44_bot_AD/Camera 230 mm Ceta 20210311 1436_50s_20f_area01_image.mrc
# index_num = 27
# 210311/Au/Camera 230 mm Ceta 20210311 1327.mrc
# index_num = 28
# 210311/Au/Camera 230 mm Ceta 20210311 1324.mrc
# index_num = 29
# 210311/sample48_TiGe27_top_AD/Camera 230 mm Ceta 20210311 1655_50s_20f_area05.mrc
# index_num = 30
# 210311/sample48_TiGe27_top_AD/Camera 230 mm Ceta 20210311 1620_50s_20f_area01.mrc
# index_num = 31
# 210311/sample48_TiGe27_top_AD/Camera 230 mm Ceta 20210311 1704_50s_20f_area07.mrc
# index_num = 32
# 210311/sample48_TiGe27_top_AD/Camera 230 mm Ceta 20210311 1634_50s_20f_area04.mrc
# index_num = 33
# 210311/sample48_TiGe27_top_AD/Camera 230 mm Ceta 20210311 1624_50s_20f_area02.mrc
# index_num = 34
# 210311/sample48_TiGe27_top_AD/Camera 230 mm Ceta 20210311 1659_50s_20f_area06.mrc
# index_num = 35
# 210311/sample48_TiGe27_top_AD/Camera 230 mm Ceta 20210311 1629_50s_20f_area03.mrc
# index_num = 36

# %%
dcs = [DataCube(fp) for fp in file.get_file_list_from_path("/mnt/experiment/TEM diffraction/210506",".mrc")]
indices = range(len(dcs))
for idx in indices:
    print(dcs[idx].file_path[32:])
    print("index_num =",idx)
    util.load_previous_tiff(dcs[idx])
    util.load_previous_dc_azavg(dcs[idx])
#     plt.imshow(dcs[idx].display_img)
#     plt.show()
    
    plt.plot(dcs[idx].azavg[0:300], label="original")
    plt.legend()
    
    first_derv_peak = find_first_peak(dcs[idx].azavg,1)
    second_derv_peak = find_first_peak(dcs[idx].azavg,2)
    if first_derv_peak is not None:
        plt.scatter(first_derv_peak,dcs[idx].azavg[first_derv_peak],color='r')
    if second_derv_peak is not None:
        plt.scatter(second_derv_peak,dcs[idx].azavg[second_derv_peak],color='b')
    plt.show()
# Out:
# 210506/Au/Camera 230 mm Ceta 20210506 1309.mrc
# index_num = 0
# 210506/Au/Camera 230 mm Ceta 20210506 1310.mrc
# index_num = 1
# 210506/sample59_TiGe_27p_500C_surface/Camera 230 mm Ceta 20210506 1407_60s_20f_area01.mrc
# index_num = 2
# 210506/sample59_TiGe_27p_500C_surface/Camera 230 mm Ceta 20210506 1412_60s_20f_area02.mrc
# index_num = 3
# 210506/sample59_TiGe_27p_500C_surface/Camera 230 mm Ceta 20210506 1416_60s_20f_area03.mrc
# index_num = 4
# 210506/sample59_TiGe_27p_500C_surface/Camera 230 mm Ceta 20210506 1422_70s_20f_area03.mrc
# index_num = 5
# 210506/sample59_TiGe_27p_500C_surface/Camera 230 mm Ceta 20210506 1426_60s_20f_area04.mrc
# index_num = 6
# 210506/sample59_TiGe_27p_500C_surface/Camera 230 mm Ceta 20210506 1431_60s_20f_area05.mrc
# index_num = 7
# 210506/sample59_TiGe_27p_500C_surface/Camera 230 mm Ceta 20210506 1435_60s_20f_area06.mrc
# index_num = 8
# 210506/sample59_TiGe_27p_500C_surface/Camera 230 mm Ceta 20210506 1439_60s_20f_area07.mrc
# index_num = 9
# 210506/sample59_TiGe_27p_500C_surface/Camera 230 mm Ceta 20210506 1442_60s_20f_area08.mrc
# index_num = 10
# 210506/sample59_TiGe_27p_500C_surface/Camera 230 mm Ceta 20210506 1446_60s_20f_area09.mrc
# index_num = 11
# 210506/sample59_TiGe_27p_500C_surface/Camera 230 mm Ceta 20210506 1450_60s_20f_area10.mrc
# index_num = 12
# 210506/sample59_TiGe_27p_500C_surface/Camera 230 mm Ceta 20210506 1744_50s_20f_area11.mrc
# index_num = 13
# 210506/sample59_TiGe_27p_500C_surface/Camera 230 mm Ceta 20210506 1747_50s_20f_area12.mrc
# index_num = 14
# 210506/sample59_TiGe_27p_500C_surface/Camera 230 mm Ceta 20210506 1752_50s_20f_area13.mrc
# index_num = 15
# 210506/sample60_TiGe_27p_500C_bottom/Camera 230 mm Ceta 20210506 1455_60s_20f_area01.mrc
# index_num = 16
# 210506/sample60_TiGe_27p_500C_bottom/Camera 230 mm Ceta 20210506 1500_60s_20f_area02.mrc
# index_num = 17
# 210506/sample60_TiGe_27p_500C_bottom/Camera 230 mm Ceta 20210506 1505_60s_20f_area03.mrc
# index_num = 18
# 210506/sample60_TiGe_27p_500C_bottom/Camera 230 mm Ceta 20210506 1510_60s_20f_area04.mrc
# index_num = 19
# 210506/sample60_TiGe_27p_500C_bottom/Camera 230 mm Ceta 20210506 1516_60s_20f_area05.mrc
# index_num = 20
# 210506/sample60_TiGe_27p_500C_bottom/Camera 230 mm Ceta 20210506 1520_60s_20f_area06.mrc
# index_num = 21
# 210506/sample60_TiGe_27p_500C_bottom/Camera 230 mm Ceta 20210506 1524_60s_20f_area07.mrc
# index_num = 22
# 210506/sample60_TiGe_27p_500C_bottom/Camera 230 mm Ceta 20210506 1529_60s_20f_area08.mrc
# index_num = 23
# 210506/sample60_TiGe_27p_500C_bottom/Camera 230 mm Ceta 20210506 1533_60s_20f_area09.mrc
# index_num = 24
# 210506/sample60_TiGe_27p_500C_bottom/Camera 230 mm Ceta 20210506 1758_50s_20f_area10.mrc
# index_num = 25
# 210506/sample61_TiGe_15p_500C_surface/Camera 230 mm Ceta 20210506 1537_60s_20f_area01.mrc
# index_num = 26
# 210506/sample61_TiGe_15p_500C_surface/Camera 230 mm Ceta 20210506 1540_60s_20f_area01_moreCenter.mrc
# index_num = 27
# 210506/sample61_TiGe_15p_500C_surface/Camera 230 mm Ceta 20210506 1546_60s_20f_area02.mrc
# index_num = 28
# 210506/sample61_TiGe_15p_500C_surface/Camera 230 mm Ceta 20210506 1550_60s_20f_area03.mrc
# index_num = 29
# 210506/sample61_TiGe_15p_500C_surface/Camera 230 mm Ceta 20210506 1556.mrc
# index_num = 30
# 210506/sample61_TiGe_15p_500C_surface/Camera 230 mm Ceta 20210506 1611_50s_20f_area05.mrc
# index_num = 31
# 210506/sample61_TiGe_15p_500C_surface/Camera 230 mm Ceta 20210506 1620_50s_20f_area06.mrc
# index_num = 32
# 210506/sample61_TiGe_15p_500C_surface/Camera 230 mm Ceta 20210506 1625.mrc
# index_num = 33
# 210506/sample61_TiGe_15p_500C_surface/Camera 230 mm Ceta 20210506 1629_50s_20f_area08_thick.mrc
# index_num = 34
# 210506/sample61_TiGe_15p_500C_surface/Camera 230 mm Ceta 20210506 1632_40s_20f_area08.mrc
# index_num = 35
# 210506/sample61_TiGe_15p_500C_surface/Camera 230 mm Ceta 20210506 1637_40s_20f_area09.mrc
# index_num = 36
# 210506/sample61_TiGe_15p_500C_surface/Camera 230 mm Ceta 20210506 1642_40s_20f_area10.mrc
# index_num = 37
# 210506/sample61_TiGe_15p_500C_surface/Camera 230 mm Ceta 20210506 1645_40s_20f_area11.mrc
# index_num = 38
# 210506/sample61_TiGe_15p_500C_surface/Camera 230 mm Ceta 20210506 1648_40s_20f_area12.mrc
# index_num = 39
# 210506/sample61_TiGe_15p_500C_surface/Camera 230 mm Ceta 20210506 1651.mrc
# index_num = 40
# 210506/sample61_TiGe_15p_500C_surface/Camera 230 mm Ceta 20210506 1656_40s_20f_area14.mrc
# index_num = 41
# 210506/sample61_TiGe_15p_500C_surface/Camera 230 mm Ceta 20210506 1700_50s_20f_area15.mrc
# index_num = 42
# 210506/sample61_TiGe_15p_500C_surface/Camera 230 mm Ceta 20210506 1703_50s_20f_area16.mrc
# index_num = 43
# 210506/sample62_TiGe_15p_500C_bottom/Camera 230 mm Ceta 20210506 1707_50s_20f_area01.mrc
# index_num = 44
# 210506/sample62_TiGe_15p_500C_bottom/Camera 230 mm Ceta 20210506 1711_50s_20f_area02.mrc
# index_num = 45
# 210506/sample62_TiGe_15p_500C_bottom/Camera 230 mm Ceta 20210506 1717_50s_20f_area03.mrc
# index_num = 46
# 210506/sample62_TiGe_15p_500C_bottom/Camera 230 mm Ceta 20210506 1720_50s_20f_area04.mrc
# index_num = 47
# 210506/sample62_TiGe_15p_500C_bottom/Camera 230 mm Ceta 20210506 1723_50s_20f_area05.mrc
# index_num = 48
# 210506/sample62_TiGe_15p_500C_bottom/Camera 230 mm Ceta 20210506 1728 0001_50s_20f_area06.mrc
# index_num = 49
# 210506/sample62_TiGe_15p_500C_bottom/Camera 230 mm Ceta 20210506 1731_50s_20f_area07.mrc
# index_num = 50
# 210506/sample62_TiGe_15p_500C_bottom/Camera 230 mm Ceta 20210506 1735_50s_20f_area08.mrc
# index_num = 51
# 210506/sample62_TiGe_15p_500C_bottom/Camera 230 mm Ceta 20210506 1739_50s_20f_area09.mrc
# index_num = 52
